# %%
from src.load_data import load_annotation_data

# %%
df = load_annotation_data()
# Out:
# ✅ Loaded 313.

# %%
import scipy
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree
n_clusters = 7 # Set the number of clusters

# %%
# Make figures nice and big
fig_size = [45,12]
plt.rcParams["figure.figsize"] = fig_size

X = df.drop(columns=["scene_ID", "World", "Level", "Scene"])
hier = linkage(X, method='ward', metric='euclidean') # scipy's hierarchical clustering
res = dendrogram(hier, labels=df['scene_ID'].to_numpy(), get_leaves=True) # Generate a dendrogram from the hierarchy
order = res.get('leaves') # Extract the order on papers from the dendrogram

# %%
import numpy as np
import pandas as pd
# Cut the hierarchy and turn the parcellation into a dataframe
part = np.squeeze(cut_tree(hier,n_clusters=n_clusters))

# %%
X['clusters'] = part

# %%
summary_cluster = X.groupby('clusters').mean()

# %%
summary_cluster
# Out:
#              Enemy   2-Horde   3-Horde   4-Horde      Roof       Gap  \
# clusters
# 0         0.000000  0.200000  0.214286  0.000000  0.042857  0.000000
# 1         0.111111  0.388889  0.111111  0.055556  0.222222  0.111111
# 2         0.022727  0.022727  0.113636  0.000000  0.181818  0.136364
# 3         0.645833  0.250000  0.000000  0.000000  0.000000  0.979167
# 4         0.897959  0.102041  0.244898  0.020408  0.102041  0.204082
# 5         0.447368  0.052632  0.078947  0.000000  0.078947  0.105263
# 6         0.413043  0.000000  0.000000  0.000000  0.021739  0.000000
#
#           Multiple gaps  Variable gaps  Gap enemy  Pillar gap  ...  Stair up  \
# clusters                                                       ...
# 0              0.014286       0.071429        0.0    0.042857  ...  0.028571
# 1              0.000000       0.055556        0.0    0.000000  ...  0.055556
# 2              0.000000       0.000000        0.0    0.000000  ...  0.000000
# 3              0.000000       0.000000        0.0    0.000000  ...  0.125000
# 4              0.020408       0.020408        0.0    0.000000  ...  0.020408
# 5              0.315789       0.078947        0.0    0.000000  ...  0.815789
# 6              0.000000       0.869565        0.0    0.000000  ...  0.021739
#
#           Stair down  Empty stair valley  Enemy stair valley  \
# clusters
# 0             0.0000            0.000000            0.000000
# 1             0.0000            0.055556            0.000000
# 2             0.0000            0.000000            0.000000
# 3             0.0625            0.000000            0.000000
# 4             0.0000            0.000000            0.000000
# 5             0.0000            0.000000            0.026316
# 6             0.0000            0.000000            0.000000
#
#           Gap stair valley    Reward  Moving platform  Flagpole  Beginning  \
# clusters
# 0                 0.014286  0.114286         0.042857  0.014286   0.200000
# 1                 0.000000  0.000000         0.055556  0.000000   0.000000
# 2                 0.000000  0.000000         0.000000  0.000000   0.000000
# 3                 0.000000  0.104167         0.062500  0.020833   0.041667
# 4                 0.000000  0.000000         0.020408  0.000000   0.081633
# 5                 0.000000  0.026316         0.026316  0.473684   0.026316
# 6                 0.000000  0.043478         0.478261  0.043478   0.021739
#
#           Bonus zone
# clusters
# 0           0.271429
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# 5           0.000000
# 6           0.000000
#
# [7 rows x 28 columns]

# %%
# Set threshold
threshold = 0.05
for index, row in summary_cluster.iterrows():
    # Filter, sort in descending order
    filtered_df = 
    print(filtered_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 5
#       2 threshold = 0.05
#       3 for row in summary_cluster.iterrows():
#       4     # Filter, sort in descending order
# ----> 5     filtered_df = row.sort_values(ascending=False)
#       6     print(filtered_row)
#
# AttributeError: 'tuple' object has no attribute 'sort_values'

# %%
# Out:
# (0,
#  Enemy                 0.000000
#  2-Horde               0.200000
#  3-Horde               0.214286
#  4-Horde               0.000000
#  Roof                  0.042857
#  Gap                   0.000000
#  Multiple gaps         0.014286
#  Variable gaps         0.071429
#  Gap enemy             0.000000
#  Pillar gap            0.042857
#  Valley                0.000000
#  Pipe valley           0.000000
#  Empty valley          0.000000
#  Enemy valley          0.057143
#  Roof valley           0.000000
#  2-Path                0.014286
#  3-Path                0.014286
#  Risk/Reward           0.014286
#  Stair up              0.028571
#  Stair down            0.000000
#  Empty stair valley    0.000000
#  Enemy stair valley    0.000000
#  Gap stair valley      0.014286
#  Reward                0.114286
#  Moving platform       0.042857
#  Flagpole              0.014286
#  Beginning             0.200000
#  Bonus zone            0.271429
#  Name: 0, dtype: float64)
